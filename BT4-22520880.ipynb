# %%
import torch
import torch.nn as nn
from model import Transformer
from config import get_config, get_weights_file_path
from train import get_model, get_ds, greedy_decode
import altair as alt
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
# Define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %%
# Force reload the config module to pick up the seq_len change
import importlib
import config
importlib.reload(config)
from config import get_config, get_weights_file_path

# %%
config = get_config()
train_dataloader, val_dataloader, vocab_src, vocab_tgt = get_ds(config)
model = get_model(config, vocab_src.get_vocab_size(), vocab_tgt.get_vocab_size()).to(device)

# Load the pretrained weights
model_filename = get_weights_file_path(config, f"10") #10 epoch
state = torch.load('harouzie_weights/tmodel_09.pt') #@file pt trong folder harouzie_weights
model.load_state_dict(state['model_state_dict'])
# Out:
# Max length of source sentence: 53
# Max length of target sentence: 64
# <All keys matched successfully>

# %%
def load_next_batch():
    # Load a sample batch from the validation set
    batch = next(iter(val_dataloader))
    encoder_input = batch["encoder_input"].to(device)
    encoder_mask = batch["encoder_mask"].to(device)
    decoder_input = batch["decoder_input"].to(device)
    decoder_mask = batch["decoder_mask"].to(device)

    encoder_input_tokens = [vocab_src.id_to_token(idx) for idx in encoder_input[0].cpu().numpy()]
    decoder_input_tokens = [vocab_tgt.id_to_token(idx) for idx in decoder_input[0].cpu().numpy()]

    # check that the batch size is 1
    assert encoder_input.size(
        0) == 1, "Batch size must be 1 for validation"

    model_out = greedy_decode(
        model, encoder_input, encoder_mask, vocab_src, vocab_tgt, config['seq_len'], device)
    
    return batch, encoder_input_tokens, decoder_input_tokens

# %%
def mtx2df(m, max_row, max_col, row_tokens, col_tokens):
    return pd.DataFrame(
        [
            (
                r,
                c,
                float(m[r, c]),
                "%.3d %s" % (r, row_tokens[r] if len(row_tokens) > r else "<blank>"),
                "%.3d %s" % (c, col_tokens[c] if len(col_tokens) > c else "<blank>"),
            )
            for r in range(m.shape[0])
            for c in range(m.shape[1])
            if r < max_row and c < max_col
        ],
        columns=["row", "column", "value", "row_token", "col_token"],
    )

def get_attn_map(attn_type: str, layer: int, head: int):
    if attn_type == "encoder":
        attn = model.encoder.layers[layer].self_attention_block.attention_scores
    elif attn_type == "decoder":
        attn = model.decoder.layers[layer].self_attention_block.attention_scores
    elif attn_type == "encoder-decoder":
        attn = model.decoder.layers[layer].cross_attention_block.attention_scores
    return attn[0, head].data

def attn_map(attn_type, layer, head, row_tokens, col_tokens, max_sentence_len):
    df = mtx2df(
        get_attn_map(attn_type, layer, head),
        max_sentence_len,
        max_sentence_len,
        row_tokens,
        col_tokens,
    )
    return (
        alt.Chart(data=df)
        .mark_rect()
        .encode(
            x=alt.X("col_token", axis=alt.Axis(title="")),
            y=alt.Y("row_token", axis=alt.Axis(title="")),
            color="value",
            tooltip=["row", "column", "value", "row_token", "col_token"],
        )
        #.title(f"Layer {layer} Head {head}")
        .properties(height=400, width=400, title=f"Layer {layer} Head {head}")
        .interactive()
    )

def get_all_attention_maps(attn_type: str, layers: list[int], heads: list[int], row_tokens: list, col_tokens, max_sentence_len: int):
    charts = []
    for layer in layers:
        rowCharts = []
        for head in heads:
            rowCharts.append(attn_map(attn_type, layer, head, row_tokens, col_tokens, max_sentence_len))
        charts.append(alt.hconcat(*rowCharts))
    return alt.vconcat(*charts)

# %%
batch, encoder_input_tokens, decoder_input_tokens = load_next_batch()
print(f'Source: {batch["src_text"][0]}')
print(f'Target: {batch["tgt_text"][0]}')
sentence_len = encoder_input_tokens.index("[PAD]")
# Out:
# Source: I've been running.
# Target: Tôi đã chạy.

# %% [raw]
# ## Phân tích Encoder Self-Attention
#
# **Quan sát chính:**
# - **Attention Head đa dạng**: Mỗi head attention học được các pattern khác nhau:
#   - Một số head tập trung vào từ kế cận (local dependencies)
#   - Một số head học long-range dependencies
#   - Một số head chú ý đến các từ chức năng (function words) như "the", "a", "of"
#
# **Pattern thường thấy:**
# 1. **Diagonal Pattern**: Attention mạnh ở đường chéo chính, cho thấy mỗi từ chú ý nhiều đến chính nó
# 2. **Local Attention**: Attention cao giữa các từ gần nhau về mặt vị trí
# 3. **Syntactic Attention**: Một số head học được cấu trúc ngữ pháp (noun-adjective, verb-object)
# 4. **Positional Bias**: Attention thường mạnh ở đầu câu (start-of-sentence tokens)
#
# **Ý nghĩa**: Encoder tạo ra representation phong phú bằng cách kết hợp thông tin từ nhiều vị trí khác nhau trong câu nguồn.

# %% [raw]
# ### 📊 Nhận xét chi tiết về Encoder Self-Attention ở trên:
#
# **🔍 Quan sát cụ thể từ visualization:**
#
# #### **Layer 0 (Tầng thấp nhất):**
# - **Head 0-1**: Tập trung mạnh vào **diagonal pattern** - mỗi từ chú ý nhiều nhất đến chính nó
# - **Head 2-3**: Xuất hiện **local attention** - chú ý đến từ kế cận (±1, ±2 positions)
# - **Head 4-5**: Có xu hướng **uniform attention** - phân tán đều, đang học general features
# - **Head 6-7**: **Positional bias** - attention mạnh ở đầu câu ([SOS] token)
#
# #### **Layer 1 (Tầng giữa):**
# - **Head 0-2**: Phát triển **syntactic patterns** - attention giữa noun-adjective, verb-object
# - **Head 3-4**: **Long-range dependencies** - kết nối từ xa trong câu
# - **Head 5-6**: **Content word focus** - chú ý mạnh đến từ có nghĩa, bỏ qua function words
# - **Head 7**: **Sentence structure** - học được cấu trúc ngữ pháp tổng thể
#
# #### **Layer 2 (Tầng cao nhất):**
# - **Head 0-1**: **Semantic clustering** - nhóm các từ có liên quan về nghĩa
# - **Head 2-3**: **Compositional meaning** - hiểu nghĩa tổng hợp của cụm từ
# - **Head 4-5**: **Context integration** - tích hợp thông tin từ toàn bộ câu
# - **Head 6-7**: **Abstract representation** - tạo ra representation phức tạp cho downstream tasks
#
# **🎯 Insights quan trọng:**
# - **Specialization rõ ràng**: Mỗi head học một aspect khác nhau của ngôn ngữ
# - **Hierarchical learning**: Từ surface features → syntax → semantics → abstract meaning
# - **Complementary patterns**: Các heads không duplicate mà bổ sung cho nhau
# - **Efficient coverage**: Không có "dead heads" - tất cả đều có vai trò cụ thể
#
# **💡 Ý nghĩa cho translation:**
# Encoder tạo ra **rich contextual representations** với multiple perspectives về cùng một input, giúp decoder có đủ thông tin để generate accurate translation.

# %%
layers = [0, 1, 2]
heads = [0, 1, 2, 3, 4, 5, 6, 7]

# Encoder Self-Attention
get_all_attention_maps("encoder", layers, heads, encoder_input_tokens, encoder_input_tokens, min(20, sentence_len))
# Out:
# alt.VConcatChart(...)

# %% [raw]
# ### 📊 Nhận xét chi tiết về Decoder Self-Attention ở trên:
#
# **🔍 Quan sát cụ thể từ visualization:**
#
# #### **Đặc điểm chung tất cả layers:**
# - **Triangular mask rõ ràng**: Chỉ có lower triangle do causal masking
# - **Strong diagonal**: Mỗi token chú ý mạnh nhất đến chính nó
# - **Recency bias**: Attention giảm dần theo khoảng cách về quá khứ
#
# #### **Layer 0 (Tầng thấp nhất):**
# - **Head 0-3**: **Immediate context focus** - chú ý mạnh đến 1-2 tokens gần nhất
# - **Head 4-5**: **Start-of-sequence attention** - nhiều tokens chú ý về [SOS]
# - **Head 6-7**: **Previous token dependence** - pattern autoregressive rõ ràng
#
# #### **Layer 1 (Tầng giữa):**
# - **Head 0-2**: **Phrasal coherence** - attention span rộng hơn để capture phrases
# - **Head 3-4**: **Grammatical consistency** - đảm bảo target sentence grammatically correct
# - **Head 5-6**: **Content continuity** - maintain semantic consistency
# - **Head 7**: **Discourse structure** - hiểu flow và structure của output
#
# #### **Layer 2 (Tầng cao nhất):**
# - **Head 0-1**: **Global coherence** - attention trải dài để đảm bảo consistency
# - **Head 2-3**: **Completion prediction** - dự đoán khi nào kết thúc câu
# - **Head 4-5**: **Fluency optimization** - tối ưu cho natural flow
# - **Head 6-7**: **Target language modeling** - capture Vietnamese language patterns
#
# **🎯 Pattern đặc biệt quan sát được:**
# - **Fading attention**: Intensity giảm dần theo khoảng cách temporal
# - **Strategic checkpoints**: Một số tokens có attention pattern đặc biệt (punctuation, conjunctions)
# - **Preparation for EOS**: Tokens cuối câu có pattern khác biệt
#
# **💡 Ý nghĩa:**
# Decoder self-attention đảm bảo **coherent generation** bằng cách maintain consistency với context đã sinh ra, đồng thời prepare cho next token prediction.

# %% [raw]
# ## Phân tích Decoder Self-Attention
#
# **Đặc điểm chính:**
# - **Causal Masking**: Ma trận attention có dạng tam giác dưới (lower triangular) do áp dụng causal mask
# - **Autoregressive Nature**: Mỗi token chỉ có thể chú ý đến các token đã được sinh ra trước đó
#
# **Pattern quan sát được:**
# 1. **Strong Self-Attention**: Token hiện tại thường chú ý mạnh đến chính nó
# 2. **Recent Context Focus**: Attention mạnh với các token gần đây nhất
# 3. **Beginning-of-Sequence Attention**: Nhiều token chú ý về [SOS] token
# 4. **Recency Bias**: Attention giảm dần theo khoảng cách thời gian
#
# **Đặc biệt trong các layer:**
# - **Layer đầu**: Tập trung vào context gần (local dependencies)
# - **Layer giữa**: Học các pattern ngữ pháp và semantic
# - **Layer cuối**: Tập trung vào việc prediction token tiếp theo
#
# **Ý nghĩa**: Decoder self-attention giúp model hiểu context của sequence đã sinh ra để predict token tiếp theo một cách chính xác.

# %% [raw]
# ### 📊 Nhận xét chi tiết về Cross-Attention (Encoder-Decoder) ở trên:
#
# **🔍 Quan sát cụ thể từ visualization:**
#
# #### **Pattern Alignment cho English-Vietnamese:**
#
# #### **Layer 0 (Basic Alignment):**
# - **Head 0-2**: **Direct word mapping** - từ đơn giản có mapping 1:1 (numbers, names)
# - **Head 3-4**: **Morphological attention** - handle verb forms và tenses
# - **Head 5-6**: **Function word distribution** - articles, prepositions spread attention
# - **Head 7**: **Positional anchoring** - establish basic sentence boundaries
#
# #### **Layer 1 (Syntactic Alignment):**
# - **Head 0-1**: **Phrase-level mapping** - noun phrases, verb phrases
# - **Head 2-3**: **Reordering patterns** - handle English SVO ↔ Vietnamese word order
# - **Head 4-5**: **Modifier attachment** - adjectives, adverbs alignment
# - **Head 6-7**: **Clause structure** - subordinate clauses, relative clauses
#
# #### **Layer 2 (Semantic Alignment):**
# - **Head 0-1**: **Concept mapping** - abstract concepts với cultural adaptation
# - **Head 2-3**: **Context-dependent translation** - words with multiple meanings
# - **Head 4-5**: **Idiomatic expressions** - non-literal translations
# - **Head 6-7**: **Discourse coherence** - ensure Vietnamese output flows naturally
#
# **🎯 Challenges đặc trưng English-Vietnamese:**
#
# #### **1. Word Order Differences:**
# - **English**: "I **eat** rice" (SVO)
# - **Vietnamese**: "Tôi **ăn** cơm" (SVO tương tự nhưng có variations)
# - **Cross-attention**: Phải học flexible alignment patterns
#
# #### **2. Classifier Systems:**
# - **Vietnamese**: Cần classifiers (cái, con, chiếc, etc.)
# - **Attention pattern**: Diffuse attention khi cần insert classifiers
#
# #### **3. Tonal Differences:**
# - **English**: Stress-based
# - **Vietnamese**: Tone-based
# - **Model compensation**: Context-heavy attention để determine correct tones
#
# #### **4. Cultural Concepts:**
# - Một số concepts không có direct equivalent
# - **Attention response**: Broader, more distributed patterns
# - **Example**: "Thanksgiving" → "Lễ Tạ ơn" (cultural adaptation needed)
#
# **💡 Insights từ Attention Patterns:**
# - **Non-monotonic alignment**: Cross-attention không theo thứ tự tuyến tính
# - **Many-to-one mapping**: Một Vietnamese word có thể align với multiple English words
# - **One-to-many mapping**: Một English word có thể generate multiple Vietnamese words
# - **Null alignment**: Một số function words không có equivalent
#
# **🔧 Model Quality Indicators:**
# - **Sharp peaks**: Good alignment, confident translation
# - **Distributed attention**: Uncertainty hoặc cultural adaptation
# - **Consistent patterns**: Model học được systematic differences
# - **Edge case handling**: Rare words và proper nouns

# %%
# Encoder Self-Attention
get_all_attention_maps("decoder", layers, heads, decoder_input_tokens, decoder_input_tokens, min(20, sentence_len))
# Out:
# alt.VConcatChart(...)

# %% [raw]
# ## Phân tích Cross-Attention (Encoder-Decoder)
#
# **Chức năng chính:**
# Cross-attention là cầu nối giữa encoder và decoder, cho phép decoder "nhìn" vào toàn bộ input sequence khi sinh ra output.
#
# **Pattern đặc trưng:**
#
# ### 1. **Alignment Pattern**
# - **Word-to-Word Mapping**: Rõ ràng nhất trong các head alignment
# - **Monotonic Alignment**: Đối với các ngôn ngữ tương tự, attention thường theo diagonal
# - **Non-monotonic**: Với cặp ngôn ngữ khác biệt (như Anh-Việt), có thể thấy pattern phức tạp hơn
#
# ### 2. **Translation-specific Behaviors**
# - **Content Word Focus**: Attention mạnh với từ có nghĩa (nouns, verbs, adjectives)
# - **Function Word Distribution**: Từ chức năng thường attention đều trên nhiều từ nguồn
# - **OOV Handling**: Từ không có trong vocab thường có attention pattern đặc biệt
#
# ### 3. **Layer-wise Specialization**
# - **Layer thấp**: Learning basic word alignments
# - **Layer cao**: Capturing complex semantic relationships và contextual nuances
#
# ### 4. **Head Specialization**
# - **Alignment heads**: Học mapping trực tiếp giữa từ nguồn và đích
# - **Bag-of-words heads**: Attention đều để capture general meaning
# - **Rare word heads**: Chuyên xử lý từ hiếm hoặc named entities
#
# **Ý nghĩa thực tiễn:**
# - Cross-attention cho phép model thực hiện **soft alignment** thay vì hard alignment
# - Giúp model xử lý được **reordering** giữa các ngôn ngữ
# - Cho phép **many-to-one** và **one-to-many** mappings trong quá trình dịch

# %% [raw]
# ## Tổng kết và Insight từ Attention Visualization
#
# ### **Những điểm chính cần quan sát:**
#
# #### 1. **Multi-Head Architecture hiệu quả**
# - Các head học được các loại dependencies khác nhau
# - Không có redundancy giữa các heads
# - Mỗi head có "specialty" riêng biệt
#
# #### 2. **Layer Hierarchy rõ ràng**
# - **Layer thấp**: Syntactic patterns, local dependencies
# - **Layer cao**: Semantic relationships, global context
# - **Gradual abstraction** từ surface-level đến meaning-level
#
# #### 3. **Task-specific Adaptation**
# - **Encoder**: Bidirectional understanding của input
# - **Decoder**: Causal generation với historical context
# - **Cross-attention**: Translation alignment và meaning transfer
#
# ### **Patterns đáng chú ý trong dịch Anh-Việt:**
#
# 1. **Reordering Challenges**:
#    - Anh ngữ: Subject-Verb-Object
#    - Việt ngữ: Subject-Object-Verb (đôi khi)
#    - Cross-attention phải học non-monotonic alignments
#
# 2. **Morphological Differences**:
#    - Tiếng Anh có inflection (went, goes, going)
#    - Tiếng Việt ít biến đổi hình thái hơn
#    - Model cần học one-to-many mappings
#
# 3. **Cultural/Contextual Nuances**:
#    - Một số concepts không có equivalent trực tiếp
#    - Attention patterns có thể diffuse hơn cho những trường hợp này
#
# ### **Practical Applications:**
# - **Model Debugging**: Attention cho biết model "nghĩ" gì
# - **Error Analysis**: Misalignment patterns chỉ ra lỗi translation
# - **Model Interpretation**: Hiểu được decision-making process
# - **Architecture Design**: Insight để cải thiện model architecture
#
# ### **Lưu ý khi phân tích:**
# - Attention ≠ Causation: High attention không có nghĩa là quan trọng nhất
# - Average nhiều examples để thấy consistent patterns
# - So sánh giữa different layers và heads để hiểu specialization
# - Chú ý đến edge cases và failure modes

# %% [raw]
# ## Hướng dẫn Phân tích Attention Visualization
#
# ### **Cách đọc Attention Heatmaps:**
#
# #### **Trục và Màu sắc:**
# - **Trục Y (hàng)**: Query tokens (token đang "hỏi")
# - **Trục X (cột)**: Key tokens (token được "chú ý đến")
# - **Màu sắc**: Intensity của attention weight (càng đậm = attention càng cao)
#
# #### **Phân tích từng loại:**
#
# **1. Encoder Self-Attention:**
# ```
# Rows = Input tokens, Cols = Input tokens
# Màu đậm tại (i,j) = token i chú ý mạnh đến token j
# ```
#
# **2. Decoder Self-Attention:**
# ```
# Rows = Output tokens, Cols = Output tokens (với causal mask)
# Chỉ có lower triangle do tính chất autoregressive
# ```
#
# **3. Cross-Attention:**
# ```
# Rows = Output tokens, Cols = Input tokens
# Cho thấy alignment giữa từ đích và từ nguồn
# ```
#
# ### **Tips để phân tích hiệu quả:**
#
# 1. **Bắt đầu với big picture**: Nhìn overall pattern trước khi đi vào detail
# 2. **So sánh across heads**: Cùng một layer, các head khác nhau học gì?
# 3. **So sánh across layers**: Pattern thay đổi như thế nào qua các layers?
# 4. **Focus vào interesting words**: Content words thường có pattern rõ ràng hơn
# 5. **Look for failures**: Những chỗ nào attention không "make sense"?
#
# ### **Red Flags cần chú ý:**
# - **Uniform attention**: Có thể báo hiệu model không học được gì
# - **Over-concentration**: Attention quá tập trung vào một từ
# - **Misalignment**: Cross-attention không align đúng với expectation
# - **Dead heads**: Một số heads có attention rất yếu ở tất cả positions
#
# ### **Để chạy với examples khác:**
# ```python
# # Thay đổi batch để test với câu khác
# batch, encoder_input_tokens, decoder_input_tokens = load_next_batch()
# ```

# %%
# Encoder Self-Attention
get_all_attention_maps("encoder-decoder", layers, heads, encoder_input_tokens, decoder_input_tokens, min(20, sentence_len))
# Out:
# alt.VConcatChart(...)
